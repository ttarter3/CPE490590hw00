# %% [markdown]
# # Thomas Tarter
# ## tgt0004@uah.edu

# %%
# %reload_ext autoreload
# %autoreload 2
! pip install pandas matplotlib torch seaborn scikit-learn pygame

# %% [markdown]
# # Line 1(%reload_ext autoreload)
#
# https://ipython.readthedocs.io/en/stable/interactive/magics.html#magic-load_ext
#
# as per the documentation above
#
# %reload_ext
# Reload an IPython extension by its module name.
#
# # Line 2(%autoreload 2)
#
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
#
# as per the documentation above
#
# %autoreload 2, %autoreload all
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

print("Hello, World!")
# Out:
# Hello, World!
